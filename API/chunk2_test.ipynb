# %%
from model import *
import pandas as pd

# %%
df = pd.read_csv('quarter2.csv')

# %%
df.head(1000)
# Out:
#      Unnamed: 0         n                                              title  \
# 0             0     18386                            The Death of Ivan Ilych
# 1             1   6080337                              The Year of the Flood
# 2             2  27371034                Annabel Horton, Lost Witch of Salem
# 3             3   7897851                                         Bloodlines
# 4             4  40121205    Broken Promises (Past Imperfect Mystery Book 1)
# 5             5  15784909                                          This Girl
# 6             6   6837103                                  The Kitchen House
# 7             7  43700638                Scars and Voices: And Other Stories
# 8             8      9912                            The Rules of Attraction
# 9             9     60931                                            Kindred
# 10           10     12194                                           Lord Jim
# ...

# %%
df.shape
# Out:
# (31469, 15)

# %%
chunk1 = df[:1000]

# %%
chunk1.shape
# Out:
# (1000, 15)

# %%
chunk1.columns
# Out:
# Index(['Unnamed: 0', 'n', 'title', 'author', 'rating', 'num_ratings',
#        'num_reviews', 'descrip', 'isbn', 'isbn13', 'binding', 'edition',
#        'pages', 'published_on', 'genres'],
#       dtype='object')

# %%
chunk1.rename(columns = {'Unnamed: 0':'zero'})
# Out:
#      zero         n                                              title  \
# 0       0     18386                            The Death of Ivan Ilych
# 1       1   6080337                              The Year of the Flood
# 2       2  27371034                Annabel Horton, Lost Witch of Salem
# 3       3   7897851                                         Bloodlines
# 4       4  40121205    Broken Promises (Past Imperfect Mystery Book 1)
# 5       5  15784909                                          This Girl
# 6       6   6837103                                  The Kitchen House
# 7       7  43700638                Scars and Voices: And Other Stories
# 8       8      9912                            The Rules of Attraction
# 9       9     60931                                            Kindred
# 10     10     12194                                           Lord Jim
# 11     11   3754016                                      Shadow's Edge
# ...

# %%
chunk2 = chunk1.drop(columns = 'zero')

# %%
chunk2.head(5)
# Out:
#           n                                            title  \
# 0     18386                          The Death of Ivan Ilych
# 1   6080337                            The Year of the Flood
# 2  27371034              Annabel Horton, Lost Witch of Salem
# 3   7897851                                       Bloodlines
# 4  40121205  Broken Promises (Past Imperfect Mystery Book 1)
#
#                 author rating     num_ratings      num_reviews  \
# 0          Leo Tolstoy   4.07  75,056 ratings  4,096   reviews
# 1      Margaret Atwood   4.07  94,003 ratings  7,205   reviews
# 2     Olivia Hardy Ray   4.32     271 ratings     19   reviews
# 3  Lindsay Anne Kendal   3.70     927 ratings     83   reviews
# 4         Anne  Willow   4.29   1,069 ratings     25   reviews
#
#                                              descrip        isbn  \
# 0  Hailed as one of the world's supreme masterpie...  1600964338
# 1  The times and species have been changing at a ...  0385528779
# ...

# %%
chunk2.to_csv("quarter3.csv")

# %%
chunk2 = pd.read_csv('quarter3.csv')

# %%
for idx, row in chunk2.iterrows():
    book = Book(webpage=row['n'], title=row['title'], author=row['author'], descrip=row['descrip'],
                rating=row['rating'], num_ratings=row['num_ratings'], num_reviews=row['num_reviews'], 
                isbn=row['isbn'], isbn13=row['isbn13'], binding=row['binding'], edition=row['edition'], 
                num_pages=row['pages'], published_on=row['published_on'], genres=row['genres'])
    DB.session.add(book)
    DB.session.commit()

# %%
dir()
# Out:
# ['Book',
#  'DB',
#  'In',
#  'Out',
#  '_',
#  '_11',
#  '_16',
#  '_21',
#  '_22',
#  '_27',
#  '_32',
#  '_33',
#  '_44',
#  '_46',
#  '_5',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'app',
#  'book',
#  'chunk1',
#  'chunk2',
#  'df',
#  'exit',
#  'get_ipython',
#  'idx',
#  'pd',
#  'quit',
# ...

# %%
#Cleaning CSV
try_this = pd.read_csv('try_this.csv')

# %%
try_this.head()
# Out:
#    Unnamed: 0         n                                            title  \
# 0           0     18386                          The Death of Ivan Ilych
# 1           1   6080337                            The Year of the Flood
# 2           2  27371034              Annabel Horton, Lost Witch of Salem
# 3           3   7897851                                       Bloodlines
# 4           4  40121205  Broken Promises (Past Imperfect Mystery Book 1)
#
#                 author  rating     num_ratings    num_reviews  \
# 0          Leo Tolstoy    4.07  75,056 ratings  4,096 reviews
# 1      Margaret Atwood    4.07  94,003 ratings  7,205 reviews
# 2     Olivia Hardy Ray    4.32     271 ratings     19 reviews
# 3  Lindsay Anne Kendal    3.70     927 ratings     83 reviews
# 4         Anne  Willow    4.29   1,069 ratings     25 reviews
#
#                                              descrip          isbn  \
# 0  Hailed as one of the world's supreme masterpie...  1600964338.0
# ...

# %%
#renaming unamed:0 column, then dropping it
try_this.rename(columns = {'Unnamed: 0':'zero'}, inplace=True)
try_this1 = try_this.drop(columns = 'zero')

# %%
try_this1.shape
# Out:
# (25665, 14)

# %%
try_this1.to_csv("try_this.csv")

# %%
try_this1 = pd.read_csv('try_this.csv')

# %%
better_reads.fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-b582b570a88e> in <module>
# ----> 1 better_reads.fetchall()
#
# NameError: name 'better_reads' is not defined

# %%
Book.query.all()
# Out:
# [<Book 1>,
#  <Book 2>,
#  <Book 3>,
#  <Book 4>,
#  <Book 5>,
#  <Book 6>,
#  <Book 7>,
#  <Book 8>,
#  <Book 9>,
#  <Book 10>,
#  <Book 11>,
#  <Book 12>,
#  <Book 13>,
#  <Book 14>,
#  <Book 15>,
#  <Book 16>,
#  <Book 17>,
#  <Book 18>,
#  <Book 19>,
#  <Book 20>,
#  <Book 21>,
#  <Book 22>,
#  <Book 23>,
#  <Book 24>,
#  <Book 25>,
#  <Book 26>,
#  <Book 27>,
#  <Book 28>,
#  <Book 29>,
#  <Book 30>,
#  <Book 31>,
#  <Book 32>,
#  <Book 33>,
#  <Book 34>,
#  <Book 35>,
#  <Book 36>,
#  <Book 37>,
#  <Book 38>,
#  <Book 39>,
#  <Book 40>,
#  <Book 41>,
#  <Book 42>,
#  <Book 43>,
#  <Book 44>,
#  <Book 45>,
#  <Book 46>,
#  <Book 47>,
#  <Book 48>,
#  <Book 49>,
#  <Book 50>,
#  <Book 51>,
#  <Book 52>,
#  <Book 53>,
#  <Book 54>,
#  <Book 55>,
#  <Book 56>,
#  <Book 57>,
#  <Book 58>,
#  <Book 59>,
#  <Book 60>,
#  <Book 61>,
#  <Book 62>,
#  <Book 63>,
#  <Book 64>,
#  <Book 65>,
#  <Book 66>,
#  <Book 67>,
#  <Book 68>,
#  <Book 69>,
#  <Book 70>,
#  <Book 71>,
#  <Book 72>,
# ...

# %%
DB.session.query(Book.title).all()
# Out:
# [('The Death of Ivan Ilych'),
#  ('The Year of the Flood'),
#  ('Annabel Horton, Lost Witch of Salem'),
#  ('Bloodlines'),
#  ('Broken Promises (Past Imperfect Mystery Book 1)'),
#  ('This Girl'),
#  ('The Kitchen House'),
#  ('Scars and Voices: And Other Stories'),
#  ('The Rules of Attraction'),
#  ('Kindred'),
#  ('Lord Jim'),
#  ("Shadow's Edge"),
#  ('The Long Dark Tea-Time of the Soul'),
#  ('Stone of Tears'),
#  ("The Mountain's Morning Song"),
#  ('Significance'),
#  ('Code Name Verity'),
#  ('Enna Burning'),
#  ('Bag of Bones'),
#  ("Amy & Roger's Epic Detour"),
#  ('Pleasant Day'),
#  ('The Mill on the Floss'),
#  ('Little Dorrit'),
#  ('The Constant Princess'),
#  ('Never Fade'),
#  ('Falling Up'),
#  ('Baby'),
#  ('The Sword in the Stone'),
#  ('The Road Less Traveled: A New Psychology of Love, Traditional Values and Spiritual Growth'),
#  ('The Book of Three'),
#  ('Just One Day'),
#  ('Fade Out'),
#  ('Wild Magic'),
#  ('The Magicians'),
#  ('Lord of Chaos'),
# ...

# %%
title = ('Stormbreaker')

# %%
DB.session.query(Book.title).filter(Book.title == title).one()[0]
# Out:
# 'Stormbreaker'

# %%
DB.session.query(Book.title, Book.author, Book.rating, Book.webpage).filter(Book.title == title).one()
# Out:
# ('Stormbreaker', 'Anthony Horowitz', 3.98, '136782')
